# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 14335, done.
# remote: Counting objects: 100% (466/466), done.
# remote: Compressing objects: 100% (274/274), done.
# remote: Total 14335 (delta 264), reused 337 (delta 192), pack-reused 13869
# Receiving objects: 100% (14335/14335), 8.23 MiB | 23.21 MiB/s, done.
# Resolving deltas: 100% (9740/9740), done.

# %%
# !cd ultralytics

# %%
# pip install -e '.[dev]'

# %%
import os
import shutil
import random
# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
import ultralytics
# ultralytics.checks()

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolov8/data.yaml epochs=90 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=gun
# Out:
# ...
# 100% 21.5M/21.5M [00:01<00:00, 12.6MB/s]
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/gun2/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/test_images/ show=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/35 /content/drive/MyDrive/yolov8/test_images/14.jpg: 640x416 (no detections), 399.0ms
# image 2/35 /content/drive/MyDrive/yolov8/test_images/15.jpg: 640x512 (no detections), 746.5ms
# image 3/35 /content/drive/MyDrive/yolov8/test_images/16.jpg: 448x640 (no detections), 612.6ms
# image 4/35 /content/drive/MyDrive/yolov8/test_images/17.jpg: 640x448 (no detections), 622.0ms
# image 5/35 /content/drive/MyDrive/yolov8/test_images/18.jpg: 448x640 (no detections), 581.2ms
# image 6/35 /content/drive/MyDrive/yolov8/test_images/23.jpg: 480x640 (no detections), 389.0ms
# image 7/35 /content/drive/MyDrive/yolov8/test_images/24.jpg: 448x640 1 gun, 354.0ms
# image 8/35 /content/drive/MyDrive/yolov8/test_images/25.jpg: 384x640 (no detections), 329.6ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolov8/output

# %%
# !yolo mode=export model=/content/drive/MyDrive/drone_yolov8/training_results/drone/weights/best.pt format=onnx
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 405, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 94, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 140, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 624, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 563, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
# ...
